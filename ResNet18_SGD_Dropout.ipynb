# %%
import tensorflow 
import tensorflow.keras
from keras.datasets import cifar100
import numpy as np
from keras.layers import Conv2D,MaxPooling2D,Dropout, Dense,Flatten
from keras.activations import relu
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.metrics import Precision,Recall
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
from datetime import datetime
import tensorboard
import keras

(x_train,y_train),(x_test,y_test)=cifar100.load_data()


es= EarlyStopping(monitor='val_loss', patience=3)
mc= ModelCheckpoint(filepath='ResNet18_SGD_Dropout.h5', monitor='val_loss', save_best_only=True)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

mean = x_train.mean()
std= x_train.std()
x_train=(x_train-mean)/std

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


def residual_layer( x, filters): 
  
  
  conv= Conv2D(filters, (3, 3), padding='same')(x)
  conv=(BatchNormalization())(conv)

  conv=(Dropout(0.2))(conv)

  r=Activation(relu)(conv)

  conv1=Conv2D(filters, (3, 3), padding='same')(r) 
  conv1=(BatchNormalization())(conv1)
  conv1=(Dropout(0.2))(conv1)

  return keras.layers.add([conv1,x])

def next_stage_layer(x, filters): 
  
  conv= Conv2D(filters, (3, 3),strides=2, padding='same')(x)
  conv=(BatchNormalization())(conv)
  conv=(Dropout(0.2))(conv)

  r=Activation(relu)(conv)
  conv1=Conv2D(filters, (3, 3), padding='same')(r)
  conv1=(BatchNormalization())(conv1) 
  conv1=(Dropout(0.2))(conv1)

  conv2= Conv2D(filters, (1, 1), padding='same',strides=(2,2))(x)
  conv2=(BatchNormalization())(conv2)
  conv2=(Dropout(0.2))(conv2)

  return keras.layers.add([conv1,conv2])

def resnet(input_shape):
  inputs = Input(shape=input_shape)
  
  
  conv_1 = Conv2D(64, (7, 7), padding='same',strides=1, input_shape=(32,32,3))(inputs)
  conv_1=(BatchNormalization())(conv_1)
  conv_1=(Dropout(0.2))(conv_1)

  max_pool1= MaxPooling2D((3,3),padding='same',strides=2)(conv_1)
  relu_1 = Activation(relu)(max_pool1)
 
  res_1=residual_layer(relu_1,64)
  relu_2= Activation(relu)(res_1)

  res_2=residual_layer(relu_2,64)
  relu_3= Activation(relu)(res_2)

  res_3= next_stage_layer(relu_3,128)
  relu_4= Activation(relu)(res_3)

  res_4=residual_layer(relu_4,128)
  relu_5= Activation(relu)(res_4)

  res_5= next_stage_layer(relu_5,256)
  relu_6= Activation(relu)(res_5)

  res_6=residual_layer(relu_6,256)
  relu_7= Activation(relu)(res_6)

  res_7=residual_layer(relu_7,256)
  relu_8= Activation(relu)(res_7)
  
  res_8=residual_layer(relu_8,256)
  relu_9= Activation(relu)(res_8)

  avg_pool=  x = AveragePooling2D(pool_size=4)(relu_9)
  flat= Flatten()(avg_pool)
  dense1= Dense(1000,activation='relu')(flat)
  dense1=(BatchNormalization())(dense1)
  dense1=(Dropout(0.2))(dense1)
  dense2= Dense(100,activation='softmax')(dense1)

  model = Model(inputs=inputs, outputs=dense2)
  return model

model = resnet((32,32,3))

logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy',Precision(),Recall()])
history=model.fit(x=x_train,y=y_train,epochs=100, validation_data=(x_test,y_test), callbacks=[es,mc,tensorboard_callback])

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step
# Epoch 1/100
#    1/1563 [..............................] - ETA: 0s - loss: 5.3525 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1563 [..............................] - ETA: 2:02 - loss: 5.3327 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0260s vs `on_train_batch_end` time: 0.1298s). Check your callbacks.
# 1563/1563 [==============================] - 31s 20ms/step - loss: 4.2287 - accuracy: 0.0664 - precision: 0.2386 - recall: 0.0048 - val_loss: 4.0407 - val_accuracy: 0.0958 - val_precision: 0.4280 - val_recall: 0.0107
# Epoch 2/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 3.6465 - accuracy: 0.1431 - precision: 0.4342 - recall: 0.0215 - val_loss: 3.4844 - val_accuracy: 0.1836 - val_precision: 0.5323 - val_recall: 0.0478
# Epoch 3/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 3.2918 - accuracy: 0.1994 - precision: 0.5297 - recall: 0.0483 - val_loss: 3.3356 - val_accuracy: 0.2155 - val_precision: 0.5349 - val_recall: 0.0821
# Epoch 4/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 3.0115 - accuracy: 0.2515 - precision: 0.5986 - recall: 0.0804 - val_loss: 3.0242 - val_accuracy: 0.2712 - val_precision: 0.5680 - val_recall: 0.1320
# Epoch 5/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 2.8107 - accuracy: 0.2863 - precision: 0.6397 - recall: 0.1069 - val_loss: 2.7764 - val_accuracy: 0.3091 - val_precision: 0.5708 - val_recall: 0.1609
# Epoch 6/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 2.6465 - accuracy: 0.3201 - precision: 0.6601 - recall: 0.1349 - val_loss: 2.7526 - val_accuracy: 0.3215 - val_precision: 0.5871 - val_recall: 0.1770
# Epoch 7/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 2.5120 - accuracy: 0.3468 - precision: 0.6782 - recall: 0.1599 - val_loss: 2.5926 - val_accuracy: 0.3524 - val_precision: 0.6219 - val_recall: 0.2015
# Epoch 8/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 2.3884 - accuracy: 0.3737 - precision: 0.6999 - recall: 0.1875 - val_loss: 2.5123 - val_accuracy: 0.3615 - val_precision: 0.6401 - val_recall: 0.2184
# Epoch 9/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 2.2923 - accuracy: 0.3949 - precision: 0.7052 - recall: 0.2060 - val_loss: 2.2981 - val_accuracy: 0.4096 - val_precision: 0.6571 - val_recall: 0.2706
# Epoch 10/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 2.2047 - accuracy: 0.4139 - precision: 0.7148 - recall: 0.2295 - val_loss: 2.3322 - val_accuracy: 0.4000 - val_precision: 0.6512 - val_recall: 0.2717
# Epoch 11/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 2.1189 - accuracy: 0.4328 - precision: 0.7178 - recall: 0.2502 - val_loss: 2.1825 - val_accuracy: 0.4355 - val_precision: 0.6806 - val_recall: 0.2966
# Epoch 12/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 2.0386 - accuracy: 0.4516 - precision: 0.7294 - recall: 0.2695 - val_loss: 2.1482 - val_accuracy: 0.4435 - val_precision: 0.6905 - val_recall: 0.3096
# Epoch 13/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.9742 - accuracy: 0.4642 - precision: 0.7344 - recall: 0.2860 - val_loss: 2.1567 - val_accuracy: 0.4477 - val_precision: 0.6889 - val_recall: 0.3094
# Epoch 14/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.9099 - accuracy: 0.4783 - precision: 0.7413 - recall: 0.3039 - val_loss: 2.1186 - val_accuracy: 0.4507 - val_precision: 0.6780 - val_recall: 0.3220
# Epoch 15/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.8541 - accuracy: 0.4887 - precision: 0.7465 - recall: 0.3186 - val_loss: 2.1024 - val_accuracy: 0.4614 - val_precision: 0.6871 - val_recall: 0.3471
# Epoch 16/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.7953 - accuracy: 0.5051 - precision: 0.7542 - recall: 0.3359 - val_loss: 2.0415 - val_accuracy: 0.4702 - val_precision: 0.6931 - val_recall: 0.3512
# Epoch 17/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.7478 - accuracy: 0.5157 - precision: 0.7561 - recall: 0.3486 - val_loss: 1.9991 - val_accuracy: 0.4820 - val_precision: 0.6898 - val_recall: 0.3700
# Epoch 18/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.6920 - accuracy: 0.5289 - precision: 0.7627 - recall: 0.3639 - val_loss: 2.0013 - val_accuracy: 0.4770 - val_precision: 0.7003 - val_recall: 0.3627
# Epoch 19/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.6366 - accuracy: 0.5436 - precision: 0.7704 - recall: 0.3822 - val_loss: 1.9369 - val_accuracy: 0.4980 - val_precision: 0.6912 - val_recall: 0.3905
# Epoch 20/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.5946 - accuracy: 0.5550 - precision: 0.7724 - recall: 0.3963 - val_loss: 2.0079 - val_accuracy: 0.4831 - val_precision: 0.6748 - val_recall: 0.3881
# Epoch 21/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.5528 - accuracy: 0.5622 - precision: 0.7755 - recall: 0.4110 - val_loss: 1.9667 - val_accuracy: 0.4996 - val_precision: 0.6926 - val_recall: 0.3994
# Epoch 22/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.5101 - accuracy: 0.5730 - precision: 0.7788 - recall: 0.4201 - val_loss: 1.9349 - val_accuracy: 0.5065 - val_precision: 0.6815 - val_recall: 0.4134
# Epoch 23/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.4613 - accuracy: 0.5846 - precision: 0.7838 - recall: 0.4380 - val_loss: 1.9785 - val_accuracy: 0.5019 - val_precision: 0.6747 - val_recall: 0.4092
# Epoch 24/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.4276 - accuracy: 0.5916 - precision: 0.7881 - recall: 0.4460 - val_loss: 1.8877 - val_accuracy: 0.5142 - val_precision: 0.6949 - val_recall: 0.4278
# Epoch 25/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.3848 - accuracy: 0.6046 - precision: 0.7928 - recall: 0.4598 - val_loss: 1.9110 - val_accuracy: 0.5153 - val_precision: 0.6842 - val_recall: 0.4289
# Epoch 26/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.3504 - accuracy: 0.6095 - precision: 0.7914 - recall: 0.4719 - val_loss: 1.8973 - val_accuracy: 0.5156 - val_precision: 0.6876 - val_recall: 0.4311
# Epoch 27/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.3162 - accuracy: 0.6181 - precision: 0.7979 - recall: 0.4825 - val_loss: 1.8987 - val_accuracy: 0.5140 - val_precision: 0.6766 - val_recall: 0.4271

# %%
import keras 

(x_train,y_train),(x_test,y_test)=cifar100.load_data()
y_test=to_categorical(y_test)

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


best_model= keras.models.load_model('ResNet18_SGD_Dropout.h5')
_, acc,precision,recall = best_model.evaluate(x_test, y_test)
print("Accuracy: "+str(acc*100)+"%")
print("Precision: "+str(precision*100)+"%")
print("Recall: "+str(recall*100)+"%")
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8877 - accuracy: 0.5142 - precision: 0.6949 - recall: 0.4278
# Accuracy: 51.419997215270996%
# Precision: 69.49317455291748%
# Recall: 42.77999997138977%
